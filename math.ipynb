# %% [markdown]
# <a href="https://colab.research.google.com/github/saivarun2007/ML_LAB_2026-2027/blob/main/math.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

print(math.pi)
print(math.sqrt(25))
print(math.pow(2, 3))
print(math.factorial(5))
print(math.gcd(12, 18))
print(math.log(10))
# Out:
# 3.141592653589793
# 5.0
# 8.0
# 120
# 6
# 2.302585092994046
